# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
import cufflinks as cf

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot

# %%
print(__version__)
# Out:
# 5.9.0

# %%
 init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df =pd.DataFrame(np.random.randn(100,4), columns="A B C D".split())

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df =pd.DataFrame(np.random.randn(100,4), columns="A B C D".split())

# %%
df.iplot(kind="scatter", x="A", y="B", mode= "markers", size=10)
df.iplot
# Out:
# <div>                            <div id="5fff14c8-92dc-4a2c-9ed9-60d12a36e0d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2 = pd.DataFrame({'Category':['A', 'B', 'C'], 'values':[32, 43, 50]})
df2
# Out:
#   Category  values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df2.iplot()
# Out:
# <div>                            <div id="ca8b2755-9198-4ff9-8574-c244c2c2eb70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(kind='bar')
df2.iplot(kind='pie')
# Out:
# <div>                            <div id="2267ac32-0710-47ba-9ec7-65e0a99376f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(kind='box')
# Out:
# <div>                            <div id="2ec080bb-e795-4f1e-9131-e431afa72974" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(kind='hist', x='Category', y='values')
# Out:
# <div>                            <div id="3f672e50-905e-42f7-8453-5fdd8afaf977" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(kind='box', x='A', y='B')
# Out:
# <div>                            <div id="b3edad40-5a74-4e11-875d-2fc41f83c0ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
({'x' : [1,2,3,4,5],'y' : [10,20,30,20,10],'z' : [500,400,300,100]})
# Out:
# {'x': [1, 2, 3, 4, 5], 'y': [10, 20, 30, 20, 10], 'z': [500, 400, 300, 100]}

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
df3 = pd.DataFrame({'x' :[1,2,3,4], 'y' :[10,20,30,20],'z':[500,400,300,100]})

# %%
df3.iplot('surface')
# Out:
# <div>                            <div id="7a70ee01-347f-42ab-be5c-03262ebc851e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3.iplot(kind='bar', bins=20)
# Out:
# <div>                            <div id="bbb6deb7-d9cc-4187-9c3e-fd0d4c8b85e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind="scatter", x="A", y="B", mode= "markers", size=10)
# Out:
# <div>                            <div id="572b1a1a-9bfe-43c4-88ed-76f9b0647fa7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3.iplot(kind='hist', x='A', y='B')
# Out:
# <div>                            <div id="bff7fb41-3d45-43b7-9b8c-daffaf7148ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
