# %% [markdown]
# <a href="https://colab.research.google.com/github/awaiskhan005/DATA-SCIENCE-AND-AI-/blob/main/THERMAL_PROCESS_FAILURE_PREDICT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df_geo = pd.read_csv('/content/sample_data/geothermal_data.csv')
df_measure= pd.read_csv('/content/sample_data/measurements_data.csv')

# %%
df_geo
# Out:
#                                        PK                         SK  \
# 0      COMPANY#Zaldivar#BELT#CT143#SIDE#I  TIMESTAMP#20240717_121131
# 1      COMPANY#Zaldivar#BELT#CT143#SIDE#I  TIMESTAMP#20240717_121136
# 2      COMPANY#Zaldivar#BELT#CT143#SIDE#I  TIMESTAMP#20240717_121141
# 3      COMPANY#Zaldivar#BELT#CT143#SIDE#I  TIMESTAMP#20240717_121146
# 4      COMPANY#Zaldivar#BELT#CT143#SIDE#I  TIMESTAMP#20240717_121151
# ...                                   ...                        ...
# 98633   COMPANY#Zaldivar#BELT#CT34#SIDE#I  TIMESTAMP#20241112_115910
# 98634   COMPANY#Zaldivar#BELT#CT34#SIDE#I  TIMESTAMP#20241112_115912
# 98635   COMPANY#Zaldivar#BELT#CT34#SIDE#I  TIMESTAMP#20241112_115913
# 98636   COMPANY#Zaldivar#BELT#CT34#SIDE#I  TIMESTAMP#20241112_115914
# 98637   COMPANY#Zaldivar#BELT#CT34#SIDE#I  TIMESTAMP#20241112_115916
#
#        year_geothermal        timestamp belt_name  temperature  \
# 0                 2024  17072024_121131     CT143    37.299999
# ...

# %%
df_measure
# Out:
#                 date_id  table             fault_name  month_fault  \
# 0       06242024_173424      6                objects            6
# 1       08072024_114319    102                objects            8
# 2       08212024_095930      0   misplaced-protection            8
# 3      07022024_1203401    101  absence-of-protection            7
# 4       07302024_172325     96   misplaced-protection            7
# ...                 ...    ...                    ...          ...
# 8521    10282024_181017     60                machine           10
# 8522    09172024_114936    250                  audio            9
# 8523  07102024_10.04243    239   misplaced-protection            7
# 8524    07312024_174103    164  absence-of-protection            7
# 8525  07022024_12.02713     65   misplaced-protection            7
#
#      second_fault belt_name temperature  day_fault  \
# 0              24     CT139           -       24.0
# 1              19     CT137           -        7.0
# ...
