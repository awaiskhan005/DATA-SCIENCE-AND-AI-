# %% [markdown]
# <a href="https://colab.research.google.com/github/awaiskhan005/DATA-SCIENCE-AND-AI-/blob/main/PUNJAB_AQI_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
weekly = pd.read_csv('/content/sample_data/weekly_composite_data_all.csv')

# %%
weekly.head()
# Out:
#              B1          B11          B12            B2            B3  \
# 0   6702.166667  4184.833333  3352.833333   6946.833333   6242.333333
# 1    444.000000  1860.000000   863.000000    671.000000   1338.000000
# 2     80.000000  1918.000000  1001.000000    362.666667    718.333333
# 3  13565.500000  2380.000000  2285.500000  11960.500000  10045.000000
# 4  15966.000000  6812.000000  5646.000000  12670.000000  10842.000000
#
#             B4            B5           B6           B7           B8  ...  \
# 0  5409.500000   5946.833333  6264.833333  6212.000000  6707.166667  ...
# 1   553.000000   1818.000000  5611.000000  6788.000000  6592.000000  ...
# 2   492.666667   1038.666667  2976.000000  3832.333333  3601.666667  ...
# 3  8729.000000   9020.500000  8365.500000  7926.500000  8052.000000  ...
# 4  9658.000000  10042.000000  9302.000000  8686.000000  8516.000000  ...
#
#    u_component_of_wind_10m  v_component_of_wind_10m  \
# ...

# %%
weekly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9900 entries, 0 to 9899
# Data columns (total 38 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   B1                                                     9322 non-null   float64
#  1   B11                                                    9323 non-null   float64
#  2   B12                                                    9323 non-null   float64
#  3   B2                                                     9319 non-null   float64
#  4   B3                                                     9323 non-null   float64
#  5   B4                                                     9323 non-null   float64
#  6   B5                                                     9323 non-null   float64
#  7   B6                                                     9323 non-null   float64
# ...

# %%
weekly.describe()
# Out:
#                  B1           B11          B12            B2            B3  \
# count   9322.000000   9323.000000  9323.000000   9319.000000   9323.000000
# mean    2706.323522   3036.405793  2493.621774   2650.180815   2793.858773
# std     3842.826598   1510.612603  1303.423602   3327.679483   2951.363335
# min        0.000000      0.000000    30.000000      0.000000      0.000000
# 25%      546.125000   2018.916667  1496.000000    719.250000   1033.333333
# 50%      993.000000   2648.000000  2272.500000   1247.000000   1635.500000
# 75%     3209.250000   3548.000000  3191.000000   3109.750000   3138.250000
# max    31767.000000  10079.500000  8492.500000  31688.000000  31152.000000
#
#                  B4            B5            B6            B7            B8  \
# count   9323.000000   9323.000000   9323.000000   9323.000000   9323.000000
# mean    2827.110096   3218.274920   3663.399482   3856.198649   3880.967792
# ...

# %%
weekly.shape
# Out:
# (9900, 38)

# %%
weekly
# Out:
#                 B1          B11          B12            B2            B3  \
# 0      6702.166667  4184.833333  3352.833333   6946.833333   6242.333333
# 1       444.000000  1860.000000   863.000000    671.000000   1338.000000
# 2        80.000000  1918.000000  1001.000000    362.666667    718.333333
# 3     13565.500000  2380.000000  2285.500000  11960.500000  10045.000000
# 4     15966.000000  6812.000000  5646.000000  12670.000000  10842.000000
# ...            ...          ...          ...           ...           ...
# 9895    609.000000  2844.000000  2407.000000    808.000000   1174.000000
# 9896    596.000000  2863.500000  2518.500000    980.000000   1339.500000
# 9897    552.000000  1990.500000  1510.000000    639.500000    982.500000
# 9898    709.000000  3213.000000  2928.000000    878.000000   1168.000000
# 9899    606.000000  3374.000000  3110.500000   1295.500000   1710.500000
#
#                B4            B5           B6           B7           B8  ...  \
# ...

# %%
weekly.isnull().sum()
# Out:
# B1                                                        578
# B11                                                       577
# B12                                                       577
# B2                                                        581
# B3                                                        577
# B4                                                        577
# B5                                                        577
# B6                                                        577
# B7                                                        577
# B8                                                        577
# B8A                                                       577
# B9                                                        577
# CH4_column_volume_mixing_ratio_dry_air_bias_corrected    2823
# CO_column_number_density                                  404
# Latitude                                                    0
# ...

# %%
df = pd.read_csv('/content/sample_data/locations.csv')

# %%
df
# Out:
#       id   latitude  longitude
# 0      1  32.030100  71.879210
# 1      2  32.361531  74.699502
# 2      3  30.257478  73.675744
# 3      4  33.271899  73.188238
# 4      5  30.399851  70.431850
# ..   ...        ...        ...
# 295  296  33.086954  73.120171
# 296  297  29.251913  70.983320
# 297  298  30.473824  72.061493
# 298  299  32.798478  71.275385
# 299  300  32.224554  71.322217
#
# [300 rows x 3 columns]

# %%
merg0 = pd.read_csv('/content/sample_data/merg0.csv')

# %%
merg0
# Out:
#                    date  pm10 pm2_5 carbon_monoxide nitrogen_dioxide  \
# 0       11/22/2023 0:00  82.4  53.7             435              2.5
# 1       11/22/2023 1:00  79.6  51.8             430              2.7
# 2       11/22/2023 2:00  77.8  50.6             423                3
# 3       11/22/2023 3:00  75.9  49.5             424                3
# 4       11/22/2023 4:00  81.3  52.7             443              2.3
# ...                 ...   ...   ...             ...              ...
# 386494  4/30/2024 19:00  21.7  13.3             270              9.7
# 386495  4/30/2024 20:00  19.6  12.2             280             10.4
# 386496  4/30/2024 21:00    19    12             294             11.8
# 386497  4/30/2024 22:00  19.1  12.2             313             14.8
# 386498  4/30/2024 23:00  19.9  12.8             336             18.5
#
#        sulphur_dioxide ozone dust     latitude    longitude location_id
# ...

# %%
merged_data = pd.merge(df, weekly, on=["location_id"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-f6e486324019> in <cell line: 1>()
# ----> 1 merged_data = pd.merge(df, weekly, on=["location_id"])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     735             self.right_join_keys,
#     736             self.join_names,
# --> 737         ) = self._get_merge_keys()
#     738
# ...
