# %% [markdown]
# <a href="https://colab.research.google.com/github/awaiskhan005/DATA-SCIENCE-AND-AI-/blob/main/TESLA_stock_price_project_31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline

# %%
df = pd.read_csv("/content/sample_data/Tesla.csv+-+Tesla.csv.csv")

# %%
df
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 0     6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2      7/1/2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3      7/2/2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4      7/6/2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...         ...         ...         ...         ...         ...       ...
# 1687  3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#        Adj Close
# 0      23.889999
# 1      23.830000
# 2      21.959999
# ...

# %%
df.shape
# Out:
# (1692, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1692 non-null   object
#  1   Open       1692 non-null   float64
#  2   High       1692 non-null   float64
#  3   Low        1692 non-null   float64
#  4   Close      1692 non-null   float64
#  5   Volume     1692 non-null   int64
#  6   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 92.7+ KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.215000    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1687    False
# 1688    False
# 1689    False
# 1690    False
# 1691    False
# Length: 1692, dtype: bool

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
df['Volume']. value_counts()
# Out:
# 986300     2
# 1714500    2
# 922500     2
# 729300     2
# 8998200    2
#           ..
# 884400     1
# 4343400    1
# 1758600    1
# 1527200    1
# 6475900    1
# Name: Volume, Length: 1676, dtype: int64

# %%
df.set_index("Date", inplace=True)

# %%
df
# Out:
#                  Open        High         Low       Close    Volume  \
# Date
# 6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 7/1/2010    25.000000   25.920000   20.270000   21.959999   8218800
# 7/2/2010    23.000000   23.100000   18.709999   19.200001   5139800
# 7/6/2010    20.000000   20.000000   15.830000   16.110001   6866900
# ...               ...         ...         ...         ...       ...
# 3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#             Adj Close
# Date
# 6/29/2010   23.889999
# 6/30/2010   23.830000
# 7/1/2010    21.959999
# 7/2/2010    19.200001
# ...

# %%
sns.scatterplot(y="Volume", x="Close", data=df, palette="Set2")
# Out:
# <ipython-input-14-b61a53622cfa>:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(y="Volume", x="Close", data=df, palette="Set2")
# <Axes: xlabel='Close', ylabel='Volume'>

# %%
# prompt: make  reg plot using plotly for the given data set using colours

px.scatter(df, x="Volume", y="Close", color='Close', title="Volume vs Close)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# prompt: make barplot using plt for given df

df.groupby(by=['Date']).sum().plot.bar(x='Open', y='Volume', figsize=(10, 5))
# Out:
# <Axes: xlabel='Open'>

# %%
import matplotlib.pyplot as plt

plt.style.use('default')

sns.lmplot(df, x='Open', y='Close', palette='Set2')

# %%
# prompt: make a matrix plot

sns.pairplot(df, hue="Close")

# %%
df['open'] = df['Open']

# %%
px.scatter_3d(df, x="Volume", y="Close", z="High", color="Open")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(x=df['Open'], y=df['Close'], mode='markers',
                         name='Data Points'))

fig.add_trace(go.Scatter(x=df['Open'], y=df['Close'], mode='lines',
                         name='Regression Line', line=dict(color='red'),
                         hoverinfo='skip'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# prompt: make a 3d plot other than scatter containinig 4 coloumn

px.line_3d(df, x="Volume", y="Close", z="High", color="Open")
plt.style.use("dar")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# prompt: px.scatter_3d(df, x="Volume", y="Close", z="High", color="Open")    make this code to be animated aslo

px.scatter_3d(df, x="Volume", y="Close", z="High", color="Open", animation_frame="Adj Close")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# !pip install plotly.graph_objects
# Out:
# ERROR: Could not find a version that satisfies the requirement plotly.graph_objects (from versions: none)
# ERROR: No matching distribution found for plotly.graph_objects

# %%
import plotly.graph_objects as go

# %%
# prompt: make a 3d bar plot for all four featues
import plotly.graph_objects as go
px.bar(df, x="Volume", y="Close", color="Open", barmode='group')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(df, x="Volume", y="Close", z="High", color="Open", barmode='group')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-8f6b83502139> in <cell line: 1>()
# ----> 1 px.bar(df, x="Volume", y="Close", z="High", color="Open", barmode='group')
#
# TypeError: bar() got an unexpected keyword argument 'z'

# %%
# prompt: make a heat map

df.corr()
# Out:
#                Open      High       Low     Close    Volume  Adj Close  \
# Open       1.000000  0.999623  0.999605  0.999233  0.407515   0.999233
# High       0.999623  1.000000  0.999521  0.999691  0.416466   0.999691
# Low        0.999605  0.999521  1.000000  0.999656  0.397615   0.999656
# Close      0.999233  0.999691  0.999656  1.000000  0.406907   1.000000
# Volume     0.407515  0.416466  0.397615  0.406907  1.000000   0.406907
# Adj Close  0.999233  0.999691  0.999656  1.000000  0.406907   1.000000
# open       1.000000  0.999623  0.999605  0.999233  0.407515   0.999233
#
#                open
# Open       1.000000
# High       0.999623
# Low        0.999605
# Close      0.999233
# Volume     0.407515
# Adj Close  0.999233
# open       1.000000

# %%
sns.heatmap(df.corr(), cmap="coolwarm", annot=True)
# Out:
# <Axes: >

# %%
px.bar(df, x="Volume", y="Close", color="Open", barmode='group')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# prompt: make good apealig  bar plot  using plotly

df.groupby(by=['Date']).sum().plot.bar(x='Open', y='Volume', figsize=(10, 5))
# Out:
# <Axes: xlabel='Open'>

# %%
# prompt: make  lmplot of a relation bt open and close using plotly

px.scatter(df, x="Open", y="Close", color='Close', title=" Tesla stock Open vs Close")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(df, x='Open', y='Close')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# prompt: make a box plot using plotly

fig = px.box(df, x='Open', y='Close')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.violin(df, x='Open', y='Close')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
